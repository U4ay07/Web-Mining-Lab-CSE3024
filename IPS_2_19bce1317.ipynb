# %% [markdown]
# # Machine Learning IPS 2
# ## CSE4020
# ### Date: 27-01-2022

# %% [markdown]
# ### <i> Name: Nagireddi Uday </i>
# ### <i> Reg. No.: 19bce1317 </i>
# ### <i>Prof: Dr. Jeganathan L </i>
# ### <i>Slot: L49 + L50 </i>

# %% [markdown]
# ## Code of Academic Integrity
# I affirm that
# * This work is my own original work and is not a borrowed work, either from other students or from assignments for other courses.
# * I have not given or received any unauthorized help on this assignment.
# * This submission is free from
#     - Plagiarism
#     - Fabrication of facts
#     - Unauthorized assistance
#     - Collusion

# %% [markdown]
# ## Visualisations in Python - Matplotlib

# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
xpoints = np.array([10, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# #### Draw a line in a diagram from position (1, 3) to position (8, 10):

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %% [markdown]
# #### To plot only the markers, you can use shortcut string notation parameter 'o', which means 'rings'., plotting without lines

# %%
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# #### Multiple Points You can plot as many points as you like, just make sure you have the same number of points in both axis.

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %% [markdown]
# #### Default X-Points If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3, (etc. depending on the length of the y-points.
#
# So, if we take the same example as above, and leave out the x-points, the diagram will look like this:

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints)
plt.show()

# %% [markdown]
# #### Mark each point with a circle:

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, marker='o')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7, 2, 9])

plt.plot(ypoints, marker='*')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, 'D:g') # D -> diamond shape, : -> dotted line, g -> green colour
plt.show()

# %% [markdown]
# #### Marker size

# %%
plt.plot(ypoints, marker = 'o', ms = 20) # D -> diamond shape, : -> dotted line, g -> green colour
plt.show()

# %% [markdown]
# #### markeredgecolor or the shorter mec to set the color of the edge of the markers:

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
plt.show()

# %% [markdown]
# #### markerfacecolor or the shorter mfc to set the color inside the edge of the markers:

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mfc = 'r')
plt.show()

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r', mfc = 'g')
plt.show()

# %% [markdown]
# #### Hexadecimal colour codes

# %%
plt.plot(ypoints, marker = 'o', ms = 20, mec = '#4CAF10', mfc = '#4CAF50')

# %% [markdown]
# #### Linestyle, or shorter ls, to change the style of the plotted line:

# %%
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
plt.plot(ypoints, linestyle = 'dashed')

# %% [markdown]
# dotted can be written as ':'

# %% [markdown]
# dashed can be written as '--'

# %%
plt.plot(ypoints, ls = ':')

# %% [markdown]
# #### Line Color

# %%
plt.plot(ypoints, color = 'r')
plt.show()

# %% [markdown]
# #### Line Width
# You can use the keyword argument linewidth or the shorter lw to change the width of the line.
#
# The value is a floating number, in points:

# %%
plt.plot(ypoints, linewidth = '20.5')
plt.show()

# %% [markdown]
# #### Multiple Lines
#
# You can plot as many lines as you like by simply adding more plt.plot() functions:

# %%
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %% [markdown]
# #### Draw two lines by specifying the x- and y- point values for both lines:

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %% [markdown]
# #### Create Lables for a Plot
# With Pyplot, you can use the xlabel() and ylabel() functions to set a label for the x- and y-axis.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Energy")
plt.ylabel("Calorie")

plt.show()

# %% [markdown]
# #### Create a Title for a Plot
#
# With Pyplot, you can use the title() function to set a title for the plot.

# %%
plt.plot(x, y)

plt.title("Energy Vs Calorie")
plt.xlabel("Energy")
plt.ylabel("Calorie ")
plt.show()

# %% [markdown]
# #### Set Font Properties for Title and Labels
#
# You can use the fontdict parameter in xlabel(), ylabel(), and title() to set font properties for the title and labels.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Energy Vs Calorie", fontdict = font1)
plt.xlabel("Energy", fontdict = font2)
plt.ylabel("Calorie ", fontdict = font2)

plt.plot(x, y)
plt.show()

# %% [markdown]
# #### Position the Title
#
# You can use the loc parameter in title() to position the title.
#
# Legal values are: 'left', 'right', and 'center'. Default value is 'center'.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Energy Vs Calorie", loc = 'left')
plt.xlabel("Energy")
plt.ylabel("Calorie ")

plt.plot(x, y)
plt.show()

# %% [markdown]
# #### Add Grid Lines to a Plot
#
# With Pyplot, you can use the grid() function to add grid lines to the plot.

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Energy Vs Calorie", loc = 'left')
plt.xlabel("Energy")
plt.ylabel("Calorie ")
plt.grid()
plt.plot(x, y)
plt.show()

# %%
plt.title("Energy Vs Calorie", loc = 'left')
plt.xlabel("Energy")
plt.ylabel("Calorie ")
plt.grid(axis='x')
plt.plot(x, y)
plt.show()

# %%
plt.title("Energy Vs Calorie", loc = 'left')
plt.xlabel("Energy")
plt.ylabel("Calorie ")
plt.grid(axis='y')
plt.plot(x, y)
plt.show()

# %% [markdown]
# #### Set Line Properties for the Grid
#
# You can also set the line properties of the grid, like this: grid(color = 'color', linestyle = 'linestyle', linewidth = number).

# %%
plt.title("Energy Vs Calorie", loc = 'left')
plt.xlabel("Energy")
plt.ylabel("Calorie ")
plt.grid(axis='y')
plt.plot(x, y)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %% [markdown]
# #### Display Multiple Plots
#
# With the subplots() function you can draw multiple plots in one figure:

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 3, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 3, 2)
plt.plot(x,y)

plt.subplot(1,3,3)
plt.show()

# %% [markdown]
# #### The subplots() Function
#
# The subplots() function takes three arguments that describes the layout of the figure.
#
# The layout is organized in rows and columns, which are represented by the first and second argument.
#
# The third argument represents the index of the current plot.
#
# plt.subplot(1, 2, 1) the figure has 1 row, 2 columns, and this plot is the first plot.
#
# plt.subplot(1, 2, 2) the figure has 1 row, 2 columns, and this plot is the second plot.

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %% [markdown]
# #### Title
#
# You can add a title to each plot with the title() function:

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %% [markdown]
# #### Super Title
# You can add a title to the entire figure with the suptitle() function

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("MY SHOP")
plt.show()

# %% [markdown]
# #### Creating Scatter PLots
#
# With Pyplot, you can use the scatter() function to draw a scatter plot
#
# The scatter() function plots one dot for each observation. It needs two arrays of the same length, one for the values of the x-axis, and one for values on the y-axis:

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %% [markdown]
# Draw 2 plots on the same figure:

# %%
# day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

# day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %% [markdown]
# #### Creating Bars
# With Pyplot, you can use bar() function to draw bar graphs.

# %%
x = np.array(["A","B","C","D"])
y = np.array([3, 4, 1, 10])

plt.bar(x,y)
plt.show()

# %% [markdown]
# #### Horizontal Bars
# If you want the bars to be displayed horizontally instead of vertically, use the barh() function

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["A","B","C","D"])
y = np.array([3, 4, 1, 10])

plt.barh(x,y)
plt.show()

# %%
x = np.array(["A","B","C","D"])
y = np.array([3, 4, 1, 10])

plt.bar(x,y, color = "red")
plt.show()

# %%
x = np.array(["A","B","C","D"])
y = np.array([3, 4, 1, 10])

plt.bar(x,y, width = 0.1)
plt.show()

# %% [markdown]
# The barh() takes the keyword argument height to set the height of the bars:

# %%
x = np.array(["A","B","C","D"])
y = np.array([3, 4, 1, 10])

plt.barh(x, y, height = 0.1)
plt.show()

# %% [markdown]
# #### Histogram
# A histogram is a graph showing frequency distributions.
#
# It is a graph showing the number of observations within each given interval.

# %% [markdown]
# Create Histogram In Matplotlib, we use the hist() function to create histograms.
#
# The hist() function will use an array of numbers to create a histogram, the array is sent into the function as an argument.
#
# For simplicity we use NumPy to randomly generate an array with 250 values, where the values will concentrate around 170, and the standard deviation is 10. Learn more about Normal Data Distribution in our Machine Learning Tutorial.

# %%
x = np.random.normal(170, 10, 250)
print(x)
# Out:
# [147.57487526 172.7931763  168.53067664 178.00270867 180.93094184
#  148.32772263 196.94088984 154.91817178 167.78342736 178.52186977
#  172.69618447 173.4484676  160.65778322 175.61444853 171.4194873
#  173.17430592 175.86662221 154.41065389 154.47954696 157.97936325
#  186.80373273 171.52117664 167.07169739 158.25345203 168.20000359
#  160.60081501 167.20738733 165.0501127  175.3084795  189.96871855
#  165.92158009 181.47539242 192.63948934 173.47437453 180.81176129
#  161.00269955 154.13451878 162.00158466 161.43795114 162.51196059
#  159.38608123 172.82700013 161.57231191 172.87226328 176.59046608
#  167.09563891 170.88571235 175.72156732 179.98048812 184.58442424
#  165.43180166 180.28648655 167.97990952 177.06409963 165.20734879
#  161.45691769 183.69505063 188.93226246 161.00261963 164.20267009
#  171.42047437 174.90128626 161.38205382 179.8001292  173.10010692
#  172.39983804 158.94538227 162.74589608 175.14626406 176.49554829
# ...

# %% [markdown]
# The hist() function will read the array and produce a histogram

# %%
x = np.random.normal(170, 10, 250)
# 170 is the mean, 10 is the difference, 250 is the number of datapoints

plt.hist(x)
plt.show()

# %% [markdown]
# #### Pie charts
# Creating Pie Charts With Pyplot, you can use the pie() function to draw pie charts:
#
# The size of each wedge is determined by comparing the value with all the other values, by using this formula:
#
# The value divided by the sum of all values: x/sum(x)

# %%
y = np.array([35, 25, 25, 15])

plt.pie(y)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.show()

# %% [markdown]
# #### Start Angle
# As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter.
#
# The startangle parameter is defined with an angle in degrees, default angle is 0.

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels, startangle = 90)
plt.show()

# %% [markdown]
# The explode parameter allows you to do that.
#
# The explode parameter, if specified, and not None, must be an array with one value for each wedge.
#
# Each value represents how far from the center each wedge is displayed.

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.5, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %% [markdown]
# #### Legend
# To add a list of explanation for each wedge, use the legend() function

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %% [markdown]
# #### Legend with Header
# To add a header to the legend, add the title parameter to the legend function.

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %% [markdown]
# ## Visualisations with a data set

# %%
from sklearn.datasets import load_boston

boston = load_boston()
display(boston)
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
boston_df = pd.DataFrame(boston.data, columns = boston.feature_names)
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# ...

# %%
boston_df['MEDV'] = boston.target

# %%
display(boston_df)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
boston_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
# Number of Not mising cell/rows
boston_df.notnull().sum()
# Out:
# CRIM       506
# ZN         506
# INDUS      506
# CHAS       506
# NOX        506
# RM         506
# AGE        506
# DIS        506
# RAD        506
# TAX        506
# PTRATIO    506
# B          506
# LSTAT      506
# MEDV       506
# dtype: int64

# %% [markdown]
# #### Line PLotting
# Use Line Plot for Univariate Data Analysis (Continious)

# %%
plt.figure(figsize=(18,8))
plt.plot(boston_df['AGE'])
plt.title("Age vs Rows Line Plot", fontsize = 10)
plt.xlabel("Row Indexes")
plt.ylabel("AGE")
plt.show()

# %% [markdown]
# #### Bar Plot
# Bivariate Visualozation - X must be discrete & Y can be discrete or continious

# %%
plt.figure(figsize=(15,9))
plt.bar(x = boston_df['ZN'], height = boston_df['AGE'], width = 1.5, color = 'deeppink')
plt.title("Age-ZN", fontsize = 10)
plt.xlabel('ZN')
plt.ylabel("AGE")
plt.show()

# %% [markdown]
# Histogram Frequency of Data in an interval - variance in Data Univariate Analysis of Continious

# %%
plt.figure(figsize=(13,9))
plt.hist(boston_df['MEDV'], bins = 3, color = 'darkviolet')
plt.title("Histogram Plot", fontsize = 10)
plt.xlabel("MEDV Interval")
plt.ylabel("Frequency in Range")
plt.show()

# %%
iris_df = pd.read_csv('Iris.csv')
iris_df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris_df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
plt.figure(figsize=(13,8))
plt.scatter(x = iris_df['SepalLengthCm'], y = iris_df['PetalLengthCm'], c = 'blue')
plt.title("Scatter Plot", fontsize = 10)
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length")
plt.show()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(13,8))
plt.scatter(x = iris_df['SepalLengthCm'], y = iris_df['PetalLengthCm'], c = 'r', marker='^', label = 'PetalLengthCm')
plt.scatter(x = iris_df['SepalLengthCm'], y = iris_df['PetalWidthCm'], c = 'b', marker = 'o', label = 'PetalWidthCm')
plt.title("Scatter Plot", fontsize = 10)
plt.xlabel("Sepal Length")
plt.ylabel("Petal Length/Petal Width")
plt.legend()
plt.show()

# %%
# Seaborn - Scatterplot
sns.set_style("whitegrid")
plt.figure(figsize=(13,8))
sns.scatterplot(x = 'SepalLengthCm', y = 'PetalLengthCm', data = iris_df, hue = 'Species', palette='plasma')
plt.show()

# %%
iris_df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
plt.figure(figsize=(8,8))
plt.pie(iris_df['Species'].value_counts(), autopct='%0.2f%%', labels = iris_df['Species'].unique(), 
        explode = (0, 0.1, 0.1))
plt.show() 
plt.savefig('Pie.jpg')

# %% [markdown]
# #### Distribution Plot

# %%
# Generate a random univariate 
# dataset
rs = np.random.RandomState(10)
d = rs.normal(size=100)
# Plot a simple histogram and kde 
# with binsize determined automatically
sns.distplot(d, kde=True, color="m")
# Out:
# <AxesSubplot:ylabel='Density'>
